# %%
import random
import matplotlib.pyplot as plt
from algorithm import Bees  
from generator import Generator

# %%
def print_pink(value):
    return f"\033[95m{value}\033[0m"

def run_algorithm_tests_and_plot_results():
    test_sizes = list(range(5, 105, 5))  
    algorithm_results = []
    random_results = []

    for size in test_sizes:
        size_text = print_pink(size)
        size_times_2_text = print_pink(size * 2)
        size_div_2_text = print_pink(size // 2)
        
        print(f'Running test with data size: {size_text}, {size_times_2_text}, {size_div_2_text}')
        
        random_data = generate_random_test_data(size)
        
        bees = Bees(20, random_data["airplanes"], random_data["passenger_groups"], random_data["airports"])
        final_solution, final_population, fitness_new = bees.bees_algorithm(random_data)
        
        random_solution = bees.generate_random_solution()
        random_solution_evaluation = bees.evaluate_solution(random_solution)
        
        algorithm_results.append(fitness_new)
        random_results.append(random_solution_evaluation)

    plt.plot(test_sizes, algorithm_results, label='Algorithm Result')
    plt.plot(test_sizes, random_results, label='Random Solution Result')
    plt.xlabel('Size of Test Data')
    plt.ylabel('Result')
    plt.title('Comparison of Algorithm Result with Random Solution Result')
    plt.legend()
    plt.show()

def generate_random_test_data(size):
    return Generator.generate_random_test_data(size, size * 2, size // 2)

run_algorithm_tests_and_plot_results()
# Out:
# Running test with data size: 5, 10, 2
# [number of iterations: 100] [number of airplanes used: 4] [number of different airports used: 3] [number of groups serviced: 9] [number of people serviced: 217] Fitness improved by 2000 [1.49%]
# Running test with data size: 10, 20, 5
# [number of iterations: 100] [number of airplanes used: 10] [number of different airports used: 5] [number of groups serviced: 20] [number of people serviced: 499] Fitness improved by 31360 [12.23%]
# Running test with data size: 15, 30, 7
# [number of iterations: 100] [number of airplanes used: 15] [number of different airports used: 7] [number of groups serviced: 30] [number of people serviced: 752] Fitness improved by 1200 [0.33%]
# Running test with data size: 20, 40, 10
# [number of iterations: 100] [number of airplanes used: 20] [number of different airports used: 10] [number of groups serviced: 40] [number of people serviced: 1073] Fitness improved by 0 [0.00%]
# Running test with data size: 25, 50, 12
# [number of iterations: 100] [number of airplanes used: 25] [number of different airports used: 12] [number of groups serviced: 49] [number of people serviced: 1202] Fitness improved by 31960 [5.19%]
# Running test with data size: 30, 60, 15
# [number of iterations: 100] [number of airplanes used: 30] [number of different airports used: 15] [number of groups serviced: 58] [number of people serviced: 1429] Fitness improved by 19220 [2.49%]
# Running test with data size: 35, 70, 17
# [number of iterations: 100] [number of airplanes used: 35] [number of different airports used: 15] [number of groups serviced: 64] [number of people serviced: 1709] Fitness improved by 95060 [12.68%]
# Running test with data size: 40, 80, 20
# [number of iterations: 100] [number of airplanes used: 40] [number of different airports used: 20] [number of groups serviced: 77] [number of people serviced: 1814] Fitness improved by 14920 [1.62%]
# Running test with data size: 45, 90, 22
# [number of iterations: 100] [number of airplanes used: 45] [number of different airports used: 21] [number of groups serviced: 89] [number of people serviced: 2224] Fitness improved by 63320 [6.63%]
# Running test with data size: 50, 100, 25
# [number of iterations: 100] [number of airplanes used: 50] [number of different airports used: 24] [number of groups serviced: 94] [number of people serviced: 2297] Fitness improved by 57420 [5.27%]
# Running test with data size: 55, 110, 27
# [number of iterations: 100] [number of airplanes used: 55] [number of different airports used: 26] [number of groups serviced: 104] [number of people serviced: 2576] Fitness improved by 33020 [2.72%]
# Running test with data size: 60, 120, 30
# [number of iterations: 100] [number of airplanes used: 60] [number of different airports used: 30] [number of groups serviced: 114] [number of people serviced: 2919] Fitness improved by 72740 [5.59%]
# Running test with data size: 65, 130, 32
# [number of iterations: 100] [number of airplanes used: 65] [number of different airports used: 31] [number of groups serviced: 121] [number of people serviced: 3021] Fitness improved by 69120 [4.87%]
# Running test with data size: 70, 140, 35
# [number of iterations: 100] [number of airplanes used: 70] [number of different airports used: 33] [number of groups serviced: 127] [number of people serviced: 3363] Fitness improved by 107970 [7.27%]
# Running test with data size: 75, 150, 37
# [number of iterations: 100] [number of airplanes used: 75] [number of different airports used: 34] [number of groups serviced: 135] [number of people serviced: 3311] Fitness improved by 40340 [2.40%]
# Running test with data size: 80, 160, 40
# [number of iterations: 100] [number of airplanes used: 80] [number of different airports used: 35] [number of groups serviced: 147] [number of people serviced: 3625] Fitness improved by 49180 [2.65%]
# Running test with data size: 85, 170, 42
# [number of iterations: 100] [number of airplanes used: 85] [number of different airports used: 34] [number of groups serviced: 147] [number of people serviced: 3579] Fitness improved by 22760 [1.30%]
# Running test with data size: 90, 180, 45
# [number of iterations: 100] [number of airplanes used: 90] [number of different airports used: 38] [number of groups serviced: 161] [number of people serviced: 4114] Fitness improved by 94710 [4.83%]
# Running test with data size: 95, 190, 47
# [number of iterations: 100] [number of airplanes used: 95] [number of different airports used: 41] [number of groups serviced: 175] [number of people serviced: 4367] Fitness improved by 103820 [4.72%]
# Running test with data size: 100, 200, 50
# [number of iterations: 100] [number of airplanes used: 100] [number of different airports used: 46] [number of groups serviced: 186] [number of people serviced: 4951] Fitness improved by 96740 [4.10%]
